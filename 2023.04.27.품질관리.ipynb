# %%
가나다라마바사아자차카타파하
거너더러머버서어저처커터퍼허
고노도로모보소오조초코토포호
구누두루무부수우주추쿠투푸후
그느드르므브스으즈츠크트프흐
기니디리미비시이지치키티피히

# %%
x_bar <- c(~~~~)
range <- c(~~~~)

# %%
mean(x_bar) #센터라인
mean(range) #알 바
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1a74ac4cff12> in <cell line: 1>()
# ----> 1 mean(x_bar)
#       2 mean(range)
#
# NameError: name 'mean' is not defined

# %%
plot(Xbar)
plot(x_bar, ylim=c(0,15)_) # 와이축 범위를 영에서 15로 조정``````정
abline(h=mean)
