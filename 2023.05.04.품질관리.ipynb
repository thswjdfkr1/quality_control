# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, sys
pkg_path = '/content/packages'
os.symlink('/content/drive/MyDrive/Colab Notebooks', pkg_path)
sys.path.insert(0, pkg_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-8-3cc28f94c1bf> in <cell line: 3>()
#       1 import os, sys
#       2 pkg_path = '/content/packages'
# ----> 3 os.symlink('/content/drive/MyDrive/Colab Notebooks', pkg_path)
#       4 sys.path.insert(0, pkg_path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/Colab Notebooks' -> '/content/packages'

# %%
# !pip install --target=$pkg_path git+https://github.com/lee-ju/Statistical_Quality_Control.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/lee-ju/Statistical_Quality_Control.git to /tmp/pip-req-build-npe4hqjj
#   Running command git clone --filter=blob:none --quiet https://github.com/lee-ju/Statistical_Quality_Control.git /tmp/pip-req-build-npe4hqjj
#   Resolved https://github.com/lee-ju/Statistical_Quality_Control.git to commit 92c606ccd8a7c122e7bd65b5384539c1fa7b1171
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Statistical-Quality-Control: filename=Statistical_Quality_Control-0.0.8-py3-none-any.whl size=4303 sha256=e7a35f045d8cc3fd92352e4d2edf619ad9129b64c94ed36b5cbcc279168f666f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kcbvvf5n/wheels/3e/fe/02/07da9b15a80d82a45cda2d973e37365fb0fbbe64dcbc437571
# Successfully built Statistical-Quality-Control
# ...

# %%
# !pip install --target=$pkg_path PACKAGE_NAME
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PACKAGE_NAME: filename=package_name-0.1-py3-none-any.whl size=1255 sha256=01e7e70f7a9a4a96ed21b41530c53e57527989f91347fdf0fb27647f22357479
#   Stored in directory: /root/.cache/pip/wheels/a3/36/c4/98d928f30290fb88555f848f73093f02b67c984a45c56c3e97
# Successfully built PACKAGE_NAME
# ...
